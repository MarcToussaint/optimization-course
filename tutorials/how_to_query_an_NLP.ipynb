# %% [markdown]
# ## Using a benchmark problem
# This tutorial shows how to use and query a benchmark problem.

# %%
import sys
sys.path.append('../build')
import numpy as np
import libry as ry

# %% [markdown]
# The following loads a benchmark problem, from which we get the ry.MathematicalProgram interface

# %%
#benchmark = ry.OptBenchmark_InvKin_Endeff("../rai/test/KOMO/switches/model2.g", True)
benchmark = ry.OptBench_Skeleton_Handover(ry.Arg.path)
# benchmark = ry.OptBench_Skeleton_StackAndBalance(ry.Arg.sequence)
nlp = benchmark.get()

# %%
help(nlp)
# Out:
# Help on MathematicalProgram in module libry object:
#
# class MathematicalProgram(pybind11_builtins.pybind11_object)
#  |  Method resolution order:
#  |      MathematicalProgram
#  |      pybind11_builtins.pybind11_object
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  evaluate(...)
#  |      evaluate(self: libry.MathematicalProgram, arg0: rai::Array<T>) -> Tuple[rai::Array<T>, rai::Array<T>]
#  |
#  |      query the NLP at a point $x$; returns the tuple $(phi,J)$, which is the feature vector and its Jacobian; features define cost terms, sum-of-square (sos) terms, inequalities, and equalities depending on 'getFeatureTypes'
#  |
#  |  getBounds(...)
#  |      getBounds(self: libry.MathematicalProgram) -> Tuple[rai::Array<T>, rai::Array<T>]
#  |
#  |      returns the tuple $(b_{lo},b_{up})$, where both vectors are of same dimensionality of $x$ (or size zero, if there are no bounds)
#  |
#  |  getDimension(...)
#  |      getDimension(self: libry.MathematicalProgram) -> int
#  |
#  |      return the dimensionality of $x$
#  |
#  |  getFHessian(...)
#  |      getFHessian(self: libry.MathematicalProgram, arg0: rai::Array<T>) -> rai::Array<T>
#  |
#  |      returns Hessian of the sum of $f$-terms
#  |
#  |  getFeatureTypes(...)
#  |      getFeatureTypes(self: libry.MathematicalProgram) -> rai::Array<T>
#  |
#  |      features (entries of $phi$) can be of one of (ry.OT.f, ry.OT.sos, ry.OT.ineq, ry.OT.eq), which means (cost, sum-of-square, inequality, equality). The total cost $f(x)$ is the sum of all f-terms plus sum-of-squares of sos-terms.
#  |
#  |  getInitializationSample(...)
#  |      getInitializationSample(self: libry.MathematicalProgram, previousOptima: rai::Array<T> = array(2.6555491e-316)) -> rai::Array<T>
#  |
#  |      returns a sample (e.g. uniform within bounds) to initialize an optimization -- not necessarily feasible
#  |
#  |  report(...)
#  |      report(self: libry.MathematicalProgram, arg0: int) -> str
#  |
#  |      displays semantic information on the last query
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from pybind11_builtins.pybind11_object:
#  |
#  |  __new__(*args, **kwargs) from pybind11_builtins.pybind11_type
#  |      Create and return a new object.  See help(type) for accurate signature.

# %% [markdown]
# The first method to use is `getInitializationSample`, which returns an initial x

# %%
x = nlp.getInitializationSample()

# %% [markdown]
# The most important method is `evaluate(x)`, which returns a tuple `(phi,J)`

# %%
(phi,J) = nlp.evaluate(x)
print('phi=', phi, '\nJ=', J)

# %%
#note the dimensionalities:
print('dim(x)=', nlp.getDimension())
print('dim(x)=', x.shape)
print('dim(phi)=', phi.shape)
print('dim(J)=', J.shape)
# Out:
# dim(x)= 239
# dim(x)= (239,)
# dim(phi)= (331,)
# dim(J)= (331, 239)

# %% [markdown]
# The features `phi` define all cost terms and inequality/equality constraint values. The feature types tell you, which feature entries refer to costs/constraints. For each feature, an integer is returned -- but actually it is an enum. So you can test equality with ry.OT.f, ry.OT.sos, ry.OT.ineq, or ry.OT.eq

# %%
types = nlp.getFeatureTypes()
print(types)
print(types[0] == ry.OT.f)
print(types[0] == ry.OT.sos)
print(types[0] == ry.OT.ineq)
print(types[0] == ry.OT.eq)
# Out:
# [2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 2 2 2 2 2 2 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#  4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#  4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#  4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#  4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 3 3 2 2 2 2 2 2 2 2 2
#  4 4 4 4 4 4 4 4 4 4 4 4 4 4 3 2 2 2 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#  4 4 4 4 4 3 3 2 2 2 2 2 2 2 2 2 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 3 2 2 2]
# False
# True
# False
# False

# %% [markdown]
# So, in our case, all features are sum-of-square features, the total cost function is $\sum_i \phi_i^2$, and we have no constraints.

# %% [markdown]
# Finally, the benchmark problem implement a report, which should help you to get more insight in what $x$ means and what is computed. For high verbosity it also displays something - in our case the robot in pose $x$.

# %%
# the report method generally returns some info string - internal information given by the benchmark implementation
print(nlp.report(4))
# Out:
# KOMO Problem:
#   x-dim:239  dual-dim:0
#   T:6 k:1 phases:6 stepsPerPhase:1 tau:2
#   #timeSlices:7 #totalDOFs:239 #frames:392
#     times:[2, 4, 6, 8, 10, 12]
#   computeCollisions:0
#     TASK 'F_qItself/1-#28' (-1..5)  type:sos  order:1  target:[]  scale:[0.141421, 0.141421, 0.141421, 0.141421, 0.141421, 0.141421, 0.141421, 0.141421, 0.141421, 0.141421, 0.141421, 0.141421, 0.141421, 0.141421]
#     TASK 'F_qQuaternionNorms/0-#56' (0..5)  type:eq  order:0  target:[]  scale:[3]
#     TASK 'F_Pose/1-box0' (-1..0)  type:eq  order:1  target:[]  scale:[100]
#     TASK 'F_PoseRel/1-box0-R_endeff' (0..1)  type:eq  order:1  target:[]  scale:[100]
#     TASK 'F_qZeroVel/1-box0' (1..5)  type:eq  order:1  target:[]  scale:[10]
#     TASK 'F_qZeroVel/1-box1' ()  type:eq  order:1  target:[]  scale:[10]
#     TASK 'F_Pose/1-box1' (0..1)  type:eq  order:1  target:[]  scale:[100]
#     TASK 'F_PoseRel/1-box1-L_endeff' (1..2)  type:eq  order:1  target:[]  scale:[100]
#     TASK 'F_qZeroVel/1-box1' (2..5)  type:eq  order:1  target:[]  scale:[10]
#     TASK 'F_Pose/1-box2' (2..3)  type:eq  order:1  target:[]  scale:[100]
#     TASK 'F_PoseRel/1-box2-R_endeff' (3..4)  type:eq  order:1  target:[]  scale:[100]
#     TASK 'F_qZeroVel/1-box2' (4..5)  type:eq  order:1  target:[]  scale:[10]
#     TASK 'F_Pose/1-box3' (2..3)  type:eq  order:1  target:[]  scale:[100]
#     TASK 'F_PoseRel/1-box3-L_endeff' (3..4)  type:eq  order:1  target:[]  scale:[100]
#     TASK 'F_PoseRel/1-box3-box1' (4..5)  type:eq  order:1  target:[]  scale:[100]
#     TASK 'F_PairCollision/0-R_endeff-box0' (0..0)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_PairCollision/0-table-box0' (1..1)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_PairCollision/0-L_endeff-box1' (1..1)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_PairCollision/0-box0-box1' (2..2)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_TotalForce/0-box1' (2..3)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_fex_POASurfaceDistance/0-box0-box1' (2..3)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_POASurfaceDistance/0-box0-box1' (2..3)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_PairCollision/0-box0-box1' (2..3)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_ForceIsNormal/0-box0-box1' (2..3)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_ForceIsPositive/0-box0-box1' (2..3)  type:ineq  order:0  target:[]  scale:[100]
#     TASK 'F_fex_Force/1-box0-box1' ()  type:sos  order:1  target:[]  scale:[0.01]
#     TASK 'F_fex_Force/0-box0-box1' (2..3)  type:sos  order:0  target:[]  scale:[0.01]
#     TASK 'F_fex_POA/1-box0-box1' ()  type:sos  order:1  target:[]  scale:[0.01]
#     TASK 'F_fex_POAzeroRelVel/1-box0-box1' (2..3)  type:sos  order:1  target:[]  scale:[0.1]
#     TASK 'F_PairCollision/0-R_endeff-box2' (3..3)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_PairCollision/0-box1-box2' (4..4)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_TotalForce/0-box2' (4..4)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_fex_POASurfaceDistance/0-box1-box2' (4..4)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_POASurfaceDistance/0-box1-box2' (4..4)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_PairCollision/0-box1-box2' (4..4)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_ForceIsNormal/0-box1-box2' (4..4)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_ForceIsPositive/0-box1-box2' (4..4)  type:ineq  order:0  target:[]  scale:[100]
#     TASK 'F_fex_Force/1-box1-box2' ()  type:sos  order:1  target:[]  scale:[0.01]
#     TASK 'F_fex_Force/0-box1-box2' (4..4)  type:sos  order:0  target:[]  scale:[0.01]
#     TASK 'F_fex_POA/1-box1-box2' ()  type:sos  order:1  target:[]  scale:[0.01]
#     TASK 'F_fex_POAzeroRelVel/1-box1-box2' ()  type:sos  order:1  target:[]  scale:[0.1]
#     TASK 'F_TotalForce/0-box1' (4..5)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_fex_POASurfaceDistance/0-box0-box1' (4..5)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_POASurfaceDistance/0-box0-box1' (4..5)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_PairCollision/0-box0-box1' (4..5)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_ForceIsNormal/0-box0-box1' (4..5)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_ForceIsPositive/0-box0-box1' (4..5)  type:ineq  order:0  target:[]  scale:[100]
#     TASK 'F_fex_Force/1-box0-box1' ()  type:sos  order:1  target:[]  scale:[0.01]
#     TASK 'F_fex_Force/0-box0-box1' (4..5)  type:sos  order:0  target:[]  scale:[0.01]
#     TASK 'F_fex_POA/1-box0-box1' ()  type:sos  order:1  target:[]  scale:[0.01]
#     TASK 'F_fex_POAzeroRelVel/1-box0-box1' (4..5)  type:sos  order:1  target:[]  scale:[0.1]
#     TASK 'F_PairCollision/0-L_endeff-box3' (3..3)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_PairCollision/0-box1-box3' (4..4)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_PairCollision/0-box2-box3' (4..4)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_TotalForce/0-box3' (4..4)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_fex_POASurfaceDistance/0-box1-box3' (4..4)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_POASurfaceDistance/0-box1-box3' (4..4)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_PairCollision/0-box1-box3' (4..4)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_ForceIsNormal/0-box1-box3' (4..4)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_ForceIsPositive/0-box1-box3' (4..4)  type:ineq  order:0  target:[]  scale:[100]
#     TASK 'F_fex_Force/1-box1-box3' ()  type:sos  order:1  target:[]  scale:[0.01]
#     TASK 'F_fex_Force/0-box1-box3' (4..4)  type:sos  order:0  target:[]  scale:[0.01]
#     TASK 'F_fex_POA/1-box1-box3' ()  type:sos  order:1  target:[]  scale:[0.01]
#     TASK 'F_fex_POAzeroRelVel/1-box1-box3' ()  type:sos  order:1  target:[]  scale:[0.1]
#     SWITCH  timeOfApplication=0  symbol=joint  jointType=free  fromId=54'R_endeff'  toId=2'box0'
#     SWITCH  timeOfApplication=1  symbol=joint  jointType=free  fromId=1'table'  toId=2'box0'
#     SWITCH  timeOfApplication=1  symbol=joint  jointType=free  fromId=30'L_endeff'  toId=3'box1'
#     SWITCH  timeOfApplication=2  symbol=joint  jointType=free  fromId=2'box0'  toId=3'box1'
#     SWITCH  timeOfApplication=3  symbol=joint  jointType=free  fromId=54'R_endeff'  toId=4'box2'
#     SWITCH  timeOfApplication=4  symbol=joint  jointType=free  fromId=3'box1'  toId=4'box2'
#     SWITCH  timeOfApplication=3  symbol=joint  jointType=free  fromId=30'L_endeff'  toId=5'box3'
#     SWITCH  timeOfApplication=4  symbol=joint  jointType=free  fromId=3'box1'  toId=5'box3'
#     SWITCH  timeOfApplication=2  symbol=addContact  jointType=init  fromId=2'box0'  toId=3'box1'
#     SWITCH  timeOfApplication=4  symbol=delContact  jointType=init  fromId=2'box0'  toId=3'box1'
#     SWITCH  timeOfApplication=4  symbol=addContact  jointType=init  fromId=3'box1'  toId=4'box2'
#     SWITCH  timeOfApplication=5  symbol=delContact  jointType=init  fromId=3'box1'  toId=4'box2'
#     SWITCH  timeOfApplication=4  symbol=addContact  jointType=init  fromId=2'box0'  toId=3'box1'
#     SWITCH  timeOfApplication=4  symbol=addContact  jointType=init  fromId=3'box1'  toId=5'box3'
#     SWITCH  timeOfApplication=5  symbol=delContact  jointType=init  fromId=3'box1'  toId=5'box3'
# {F_qItself/1-#28:{ order:1, type:sos, sos:5.71325e-05 },
# F_qQuaternionNorms/0-#56:{ order:0, type:eq, eq:0.769818 },
# F_Pose/1-box0:{ order:1, type:eq, eq:3.92628 },
# F_PoseRel/1-box0-R_endeff:{ order:1, type:eq, eq:2.20516 },
# F_qZeroVel/1-box0:{ order:1, type:eq, eq:9.64879 },
# F_qZeroVel/1-box1:{ order:1, type:eq },
# F_Pose/1-box1:{ order:1, type:eq, eq:2.82951 },
# F_PoseRel/1-box1-L_endeff:{ order:1, type:eq, eq:2.5929 },
# F_qZeroVel/1-box1:{ order:1, type:eq, eq:7.10849 },
# F_Pose/1-box2:{ order:1, type:eq, eq:3.01415 },
# F_PoseRel/1-box2-R_endeff:{ order:1, type:eq, eq:10.8087 },
# F_qZeroVel/1-box2:{ order:1, type:eq, eq:3.51091 },
# F_Pose/1-box3:{ order:1, type:eq, eq:2.86785 },
# F_PoseRel/1-box3-L_endeff:{ order:1, type:eq, eq:6.37635 },
# F_PoseRel/1-box3-box1:{ order:1, type:eq, eq:2.87903 },
# F_PairCollision/0-R_endeff-box0:{ order:0, type:eq, eq:61.3772 },
# F_PairCollision/0-table-box0:{ order:0, type:eq, eq:0.573199 },
# F_PairCollision/0-L_endeff-box1:{ order:0, type:eq, eq:37.5575 },
# F_PairCollision/0-box0-box1:{ order:0, type:eq, eq:4.37938 },
# F_TotalForce/0-box1:{ order:0, type:eq, eq:201.485 },
# F_fex_POASurfaceDistance/0-box0-box1:{ order:0, type:eq, eq:1.07345 },
# F_fex_POASurfaceDistance/0-box0-box1:{ order:0, type:eq, eq:0.156558 },
# F_PairCollision/0-box0-box1:{ order:0, type:eq, eq:0.800878 },
# F_fex_ForceIsNormal/0-box0-box1:{ order:0, type:eq, eq:0.430012 },
# F_fex_ForceIsPositive/0-box0-box1:{ order:0, type:ineq, ineq:0.505407 },
# F_fex_Force/1-box0-box1:{ order:1, type:sos },
# F_fex_Force/0-box0-box1:{ order:0, type:sos, sos:4.41859e-08 },
# F_fex_POA/1-box0-box1:{ order:1, type:sos },
# F_fex_POAzeroRelVel/1-box0-box1:{ order:1, type:sos, sos:2.13e-06 },
# F_PairCollision/0-R_endeff-box2:{ order:0, type:eq, eq:47.1353 },
# F_PairCollision/0-box1-box2:{ order:0, type:eq, eq:4.93054 },
# F_TotalForce/0-box2:{ order:0, type:eq, eq:102.402 },
# F_fex_POASurfaceDistance/0-box1-box2:{ order:0, type:eq, eq:0.0596812 },
# F_fex_POASurfaceDistance/0-box1-box2:{ order:0, type:eq, eq:0.48352 },
# F_PairCollision/0-box1-box2:{ order:0, type:eq, eq:0.493054 },
# F_fex_ForceIsNormal/0-box1-box2:{ order:0, type:eq, eq:0.174001 },
# F_fex_ForceIsPositive/0-box1-box2:{ order:0, type:ineq, ineq:0.666464 },
# F_fex_Force/1-box1-box2:{ order:1, type:sos },
# F_fex_Force/0-box1-box2:{ order:0, type:sos, sos:1.77338e-08 },
# F_fex_POA/1-box1-box2:{ order:1, type:sos },
# F_fex_POAzeroRelVel/1-box1-box2:{ order:1, type:sos },
# F_TotalForce/0-box1:{ order:0, type:eq, eq:204.641 },
# F_fex_POASurfaceDistance/0-box0-box1:{ order:0, type:eq, eq:1.12696 },
# F_fex_POASurfaceDistance/0-box0-box1:{ order:0, type:eq, eq:0.0959437 },
# F_PairCollision/0-box0-box1:{ order:0, type:eq, eq:1.08706 },
# F_fex_ForceIsNormal/0-box0-box1:{ order:0, type:eq, eq:0.300905 },
# F_fex_ForceIsPositive/0-box0-box1:{ order:0, type:ineq },
# F_fex_Force/1-box0-box1:{ order:1, type:sos },
# F_fex_Force/0-box0-box1:{ order:0, type:sos, sos:1.10943e-07 },
# F_fex_POA/1-box0-box1:{ order:1, type:sos },
# F_fex_POAzeroRelVel/1-box0-box1:{ order:1, type:sos, sos:8.88893e-07 },
# F_PairCollision/0-L_endeff-box3:{ order:0, type:eq, eq:50.8511 },
# F_PairCollision/0-box1-box3:{ order:0, type:eq, eq:24.9025 },
# F_PairCollision/0-box2-box3:{ order:0, type:eq, eq:9.934 },
# F_TotalForce/0-box3:{ order:0, type:eq, eq:102.402 },
# F_fex_POASurfaceDistance/0-box1-box3:{ order:0, type:eq, eq:1.12855 },
# F_fex_POASurfaceDistance/0-box1-box3:{ order:0, type:eq, eq:1.37644 },
# F_PairCollision/0-box1-box3:{ order:0, type:eq, eq:2.49025 },
# F_fex_ForceIsNormal/0-box1-box3:{ order:0, type:eq, eq:0.166663 },
# F_fex_ForceIsPositive/0-box1-box3:{ order:0, type:ineq },
# F_fex_Force/1-box1-box3:{ order:1, type:sos },
# F_fex_Force/0-box1-box3:{ order:0, type:sos, sos:1.61172e-08 },
# F_fex_POA/1-box1-box3:{ order:1, type:sos },
# F_fex_POAzeroRelVel/1-box1-box3:{ order:1, type:sos },
# sos:6.03403e-05,
# ineq:1.17187,
# eq:922.553,
# f:0}

# %% [markdown]
# ## demo for testing
# Calling the rai optimizer as below is just for testing - you're supposed to instead implement your own solvers!

# %%
#setup a solver with that problem
solver = ry.NLP_Solver()
solver.setProblem(nlp)
#solver.setSolver(ry.NLP_SolverID.newton)
solver.setSolver(ry.NLP_SolverID.augmentedLag)

# %%
#solve it
solver.solve(True)
# Out:
# array([ -4.80260966e-02,   5.68230854e-02,  -4.77892129e-02,
#         -9.25782228e-01,  -3.49027995e-01,   1.38815096e-01,
#          4.88494601e-02,  -8.26641542e-03,  -3.15379013e-01,
#         -2.94562374e-02,  -1.28957006e+00,  -6.28283526e-03,
#         -1.29285368e+00,   1.44414872e-02,   4.00427962e-01,
#         -7.22610173e-01,   2.98734935e-01,  -1.46884096e+00,
#          4.33346522e-01,  -1.44458388e+00,   4.06495973e-01,
#         -1.41584075e-01,   4.34691849e-02,   1.09718292e-01,
#         -7.71154626e-01,  -5.03488785e-01,  -2.11752516e-01,
#         -3.27765566e-01,   1.66874518e-01,   5.35813806e-02,
#         -8.99987806e-02,  -9.42388061e-01,  -9.34621014e-02,
#         -1.14465833e-01,  -3.00399795e-01,  -2.57798293e-01,
#         -7.00669883e-01,  -2.52680710e-01,  -1.21873796e+00,
#         -9.48538684e-02,  -1.39034128e+00,   1.76301941e-01,
#          3.64864121e-01,  -7.41271136e-01,   4.14669009e-01,
#         -1.33270911e+00,   1.81073085e-02,  -7.41830395e-01,
#         -4.26185681e-01,  -1.41572919e-01,   4.34822408e-02,
#          1.09767817e-01,  -7.69133214e-01,  -5.04773155e-01,
#         -2.17282723e-01,  -3.27095851e-01,  -2.99345135e-02,
#          7.33614524e-02,   4.06656042e-02,   9.14710447e-01,
#         -3.97323817e-01,  -3.71522719e-02,  -7.44051365e-02,
#         -2.28281022e-01,  -7.66914617e-02,  -1.68545824e-01,
#         -1.70588339e+00,   3.54765008e-02,  -1.22168958e+00,
#         -4.05987084e-01,   6.66540350e-02,  -3.54553960e-01,
#          5.44019892e-02,  -1.27530270e+00,   2.41668047e-03,
#         -1.25585048e+00,   1.31213873e-02,  -1.41572332e-01,
#          4.34921171e-02,   1.09804352e-01,  -7.65670117e-01,
#         -5.08446419e-01,  -2.18874082e-01,  -3.28335084e-01,
#         -2.99750805e-02,   7.29549657e-02,   4.02485511e-02,
#          9.15666616e-01,  -3.95014660e-01,  -3.42086996e-02,
#         -7.56899557e-02,  -4.79751616e-02,   6.24972718e-02,
#         -4.85058776e-02,  -9.94399487e-01,  -5.80380379e-02,
#          8.85749265e-02,  -4.03555849e-03,   2.29690070e-02,
#          4.62063279e-02,  -8.30580865e-02,  -9.52924497e-01,
#          2.09996552e-01,  -9.45608010e-02,  -1.97301973e-01,
#         -4.27582298e-01,  -7.91012372e-01,  -1.53468623e-01,
#         -1.11126055e+00,   8.01900020e-02,  -7.83394287e-01,
#         -1.45481572e-01,   4.79772562e-01,  -8.67216025e-01,
#          1.58461773e-01,  -8.93751742e-01,   9.30799403e-02,
#         -1.38602948e+00,   5.73768629e-01,  -1.41572947e-01,
#          4.35026238e-02,   1.09840120e-01,  -7.59871523e-01,
#         -5.15654813e-01,  -2.20218699e-01,  -3.29826817e-01,
#         -3.00191148e-02,   7.25036285e-02,   4.00554726e-02,
#          9.16840871e-01,  -3.92133254e-01,  -3.22019013e-02,
#         -7.69794249e-02,   8.23482805e-03,   1.18393335e-01,
#          7.93728122e-02,   9.19297581e-01,   7.93025885e-02,
#          1.65362387e-01,  -3.49285534e-01,   1.39217072e-01,
#          1.01309448e-01,   7.79019239e-02,   9.06914572e-01,
#         -3.45274107e-01,  -1.35519589e-01,  -2.00983155e-01,
#         -2.02307112e-01,  -3.82148883e-01,  -1.61782903e-01,
#         -1.25289021e+00,  -3.11741555e-01,  -1.19777509e+00,
#         -1.63162811e-01,   2.92683706e-01,  -4.85584008e-01,
#          3.97360942e-01,  -1.53873477e+00,   6.83435772e-01,
#         -6.09745949e-01,   1.00673298e-01,  -1.41571700e-01,
#          4.35019585e-02,   1.09840796e-01,  -7.62505775e-01,
#         -5.11627951e-01,  -2.19787625e-01,  -3.30072213e-01,
#         -2.99930888e-02,   7.25956987e-02,   3.97898035e-02,
#          9.16588114e-01,  -3.92998395e-01,  -3.19613405e-02,
#         -7.66286203e-02,   8.23521260e-03,   1.18393898e-01,
#          7.93726318e-02,   9.19362020e-01,   7.90806374e-02,
#          1.64882300e-01,  -3.49358530e-01,   1.39217591e-01,
#          1.01309937e-01,   7.79020648e-02,   9.06911346e-01,
#         -3.45277423e-01,  -1.35522879e-01,  -2.00984498e-01,
#         -1.81709484e-02,  -2.84854526e-01,   8.48571760e-03,
#         -1.27876466e+00,  -1.92575769e-02,  -1.32244344e+00,
#         -4.91350377e-02,   1.63485687e-03,  -3.27790658e-01,
#          1.87544589e-02,  -1.30253652e+00,   2.87962743e-02,
#         -1.28591035e+00,   2.11180999e-02,  -1.55947340e-01,
#          1.63078496e-02,   7.69728020e-01,   1.96661276e-06,
#          3.50381065e-06,  -9.99999914e-01,  -1.55644493e-01,
#          1.57221837e-02,   7.68253536e-01,  -1.09475156e-06,
#          4.88976810e-06,  -9.99999922e-01,  -1.92279621e-01,
#          8.70541699e-02,   8.39525058e-01,   2.96675932e-06,
#         -1.84170482e-05,  -9.99997499e-01,  -1.42415859e-01,
#          8.54083709e-02,   7.69525431e-01,   2.70929859e-07,
#         -3.37206370e-05,  -2.99999697e+00,  -1.55505253e-01,
#          1.52111720e-02,   7.67244954e-01,  -2.38770096e-06,
#          5.17127456e-06,  -9.99999922e-01,  -8.00979380e-02,
#          1.54942035e-01,   8.35960648e-01,  -3.16372443e-07,
#         -7.39172975e-06,  -9.99998233e-01])

# %%
solver.getTrace_x()
# Out:
# array([[ -4.97831591e-01,  -4.78137445e-01,  -1.50663069e-01, ...,
#           2.12807887e-02,   9.02864704e-03,  -9.57494335e-03],
#        [ -4.82680681e-01,  -4.67712644e-01,  -1.67444410e-01, ...,
#           2.10583491e-02,   8.86721985e-03,  -2.88747077e-02],
#        [ -4.55883452e-01,  -4.49123628e-01,  -1.73056256e-01, ...,
#           2.00010031e-02,   7.21924317e-03,  -7.09936426e-02],
#        ...,
#        [ -4.80260709e-02,   5.68230637e-02,  -4.77892712e-02, ...,
#          -3.16372595e-07,  -7.39173629e-06,  -9.99998233e-01],
#        [ -4.80260812e-02,   5.68230724e-02,  -4.77892479e-02, ...,
#          -3.16372534e-07,  -7.39173368e-06,  -9.99998233e-01],
#        [ -4.80260966e-02,   5.68230854e-02,  -4.77892129e-02, ...,
#          -3.16372443e-07,  -7.39172975e-06,  -9.99998233e-01]])

# %%
#the first is total cost, 2nd is ineq, 3rd is eq
solver.getTrace_costs()
# Out:
# array([[  1.44578254e-04,   6.81067818e+00,   9.58271848e+02],
#        [  1.83081491e-03,   5.06009148e+00,   9.50332756e+02],
#        [  8.39637747e-03,   5.80959711e+00,   9.32980485e+02],
#        [  9.31484652e-03,   0.00000000e+00,   8.80556115e+02],
#        [  1.42554381e-02,   0.00000000e+00,   8.24491330e+02],
#        [  1.58414246e-02,   0.00000000e+00,   7.60520827e+02],
#        [  1.74896422e-02,   0.00000000e+00,   6.94497215e+02],
#        [  1.88032638e-02,   0.00000000e+00,   6.27856641e+02],
#        [  2.09652325e-02,   0.00000000e+00,   5.60947159e+02],
#        [  2.07568892e-02,   0.00000000e+00,   4.93776251e+02],
#        [  2.21019925e-02,   0.00000000e+00,   4.26153494e+02],
#        [  2.34033852e-02,   0.00000000e+00,   3.58216669e+02],
#        [  2.56825109e-02,   0.00000000e+00,   2.88993770e+02],
#        [  2.85167699e-02,   0.00000000e+00,   2.19831884e+02],
#        [  3.27098806e-02,   0.00000000e+00,   1.51556983e+02],
#        [  3.87935043e-02,   0.00000000e+00,   8.28748651e+01],
#        [  4.76137008e-02,   0.00000000e+00,   2.00311880e+01],
#        [  5.12161552e-02,   0.00000000e+00,   4.87088295e+00],
#        [  5.24678739e-02,   0.00000000e+00,   4.03785902e+00],
#        [  5.18110754e-02,   0.00000000e+00,   2.92334726e+00],
#        [  5.26322997e-02,   0.00000000e+00,   9.56470033e+00],
#        [  5.22070455e-02,   0.00000000e+00,   4.39373264e+00],
#        [  5.20054000e-02,   0.00000000e+00,   2.53603186e+00],
#        [  5.22889881e-02,   0.00000000e+00,   5.94021647e+00],
#        [  5.21452543e-02,   0.00000000e+00,   4.02087651e+00],
#        [  5.20748422e-02,   0.00000000e+00,   3.09124152e+00],
#        [  5.20399999e-02,   0.00000000e+00,   2.63687201e+00],
#        [  5.20226696e-02,   0.00000000e+00,   2.52015061e+00],
#        [  5.20413149e-02,   0.00000000e+00,   2.48128096e+00],
#        [  5.20582837e-02,   0.00000000e+00,   2.42596908e+00],
#        [  5.20984903e-02,   0.00000000e+00,   2.34943186e+00],
#        [  5.21329099e-02,   0.00000000e+00,   2.23142827e+00],
#        [  5.26862505e-02,   0.00000000e+00,   2.08581809e+00],
#        [  5.33899280e-02,   0.00000000e+00,   1.61476634e+01],
#        [  5.30288410e-02,   0.00000000e+00,   9.29000189e+00],
#        [  5.28552337e-02,   0.00000000e+00,   5.56459465e+00],
#        [  5.27701641e-02,   0.00000000e+00,   3.72506814e+00],
#        [  5.27280628e-02,   0.00000000e+00,   2.82652556e+00],
#        [  5.27071206e-02,   0.00000000e+00,   2.38473150e+00],
#        [  5.26966765e-02,   0.00000000e+00,   2.17386770e+00],
#        [  5.26914613e-02,   0.00000000e+00,   2.11736527e+00],
#        [  5.26888553e-02,   0.00000000e+00,   2.09931075e+00],
#        [  5.26875528e-02,   0.00000000e+00,   2.09029415e+00],
#        [  5.26869016e-02,   0.00000000e+00,   2.08578855e+00],
#        [  5.26873428e-02,   0.00000000e+00,   2.08525671e+00],
#        [  5.26880049e-02,   0.00000000e+00,   2.08445952e+00],
#        [  5.26889989e-02,   0.00000000e+00,   2.08326498e+00],
#        [  5.26904920e-02,   0.00000000e+00,   2.08155172e+00],
#        [  5.27000577e-02,   0.00000000e+00,   2.15877577e+00],
#        [  5.26952730e-02,   0.00000000e+00,   2.11318684e+00],
#        [  5.26928820e-02,   0.00000000e+00,   2.09732118e+00],
#        [  5.26916869e-02,   0.00000000e+00,   2.08939601e+00],
#        [  5.26910894e-02,   0.00000000e+00,   2.08543535e+00],
#        [  5.26907907e-02,   0.00000000e+00,   2.08345551e+00],
#        [  5.26906414e-02,   0.00000000e+00,   2.08246571e+00],
#        [  5.26905667e-02,   0.00000000e+00,   2.08197084e+00],
#        [  5.26905294e-02,   0.00000000e+00,   2.08172341e+00],
#        [  5.26905107e-02,   0.00000000e+00,   2.08159970e+00],
#        [  5.26905014e-02,   0.00000000e+00,   2.08154830e+00],
#        [  5.26905154e-02,   0.00000000e+00,   2.08163063e+00],
#        [  5.26905084e-02,   0.00000000e+00,   2.08158423e+00],
#        [  5.26905049e-02,   0.00000000e+00,   2.08156104e+00],
#        [  5.26905031e-02,   0.00000000e+00,   2.08154944e+00],
#        [  5.26905045e-02,   0.00000000e+00,   2.08154864e+00],
#        [  5.26905065e-02,   0.00000000e+00,   2.08154745e+00],
#        [  5.26905096e-02,   0.00000000e+00,   2.08154566e+00]])

# %%
print(nlp.report(4))
# Out:
# KOMO Problem:
#   x-dim:239  dual-dim:0
#   T:6 k:1 phases:6 stepsPerPhase:1 tau:2
#   #timeSlices:7 #totalDOFs:239 #frames:392
#     times:[2, 4, 6, 8, 10, 12]
#   computeCollisions:0
#     TASK 'F_qItself/1-#28' (-1..5)  type:sos  order:1  target:[]  scale:[0.141421, 0.141421, 0.141421, 0.141421, 0.141421, 0.141421, 0.141421, 0.141421, 0.141421, 0.141421, 0.141421, 0.141421, 0.141421, 0.141421]
#     TASK 'F_qQuaternionNorms/0-#56' (0..5)  type:eq  order:0  target:[]  scale:[3]
#     TASK 'F_Pose/1-box0' (-1..0)  type:eq  order:1  target:[]  scale:[100]
#     TASK 'F_PoseRel/1-box0-R_endeff' (0..1)  type:eq  order:1  target:[]  scale:[100]
#     TASK 'F_qZeroVel/1-box0' (1..5)  type:eq  order:1  target:[]  scale:[10]
#     TASK 'F_qZeroVel/1-box1' ()  type:eq  order:1  target:[]  scale:[10]
#     TASK 'F_Pose/1-box1' (0..1)  type:eq  order:1  target:[]  scale:[100]
#     TASK 'F_PoseRel/1-box1-L_endeff' (1..2)  type:eq  order:1  target:[]  scale:[100]
#     TASK 'F_qZeroVel/1-box1' (2..5)  type:eq  order:1  target:[]  scale:[10]
#     TASK 'F_Pose/1-box2' (2..3)  type:eq  order:1  target:[]  scale:[100]
#     TASK 'F_PoseRel/1-box2-R_endeff' (3..4)  type:eq  order:1  target:[]  scale:[100]
#     TASK 'F_qZeroVel/1-box2' (4..5)  type:eq  order:1  target:[]  scale:[10]
#     TASK 'F_Pose/1-box3' (2..3)  type:eq  order:1  target:[]  scale:[100]
#     TASK 'F_PoseRel/1-box3-L_endeff' (3..4)  type:eq  order:1  target:[]  scale:[100]
#     TASK 'F_PoseRel/1-box3-box1' (4..5)  type:eq  order:1  target:[]  scale:[100]
#     TASK 'F_PairCollision/0-R_endeff-box0' (0..0)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_PairCollision/0-table-box0' (1..1)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_PairCollision/0-L_endeff-box1' (1..1)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_PairCollision/0-box0-box1' (2..2)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_TotalForce/0-box1' (2..3)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_fex_POASurfaceDistance/0-box0-box1' (2..3)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_POASurfaceDistance/0-box0-box1' (2..3)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_PairCollision/0-box0-box1' (2..3)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_ForceIsNormal/0-box0-box1' (2..3)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_ForceIsPositive/0-box0-box1' (2..3)  type:ineq  order:0  target:[]  scale:[100]
#     TASK 'F_fex_Force/1-box0-box1' ()  type:sos  order:1  target:[]  scale:[0.01]
#     TASK 'F_fex_Force/0-box0-box1' (2..3)  type:sos  order:0  target:[]  scale:[0.01]
#     TASK 'F_fex_POA/1-box0-box1' ()  type:sos  order:1  target:[]  scale:[0.01]
#     TASK 'F_fex_POAzeroRelVel/1-box0-box1' (2..3)  type:sos  order:1  target:[]  scale:[0.1]
#     TASK 'F_PairCollision/0-R_endeff-box2' (3..3)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_PairCollision/0-box1-box2' (4..4)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_TotalForce/0-box2' (4..4)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_fex_POASurfaceDistance/0-box1-box2' (4..4)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_POASurfaceDistance/0-box1-box2' (4..4)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_PairCollision/0-box1-box2' (4..4)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_ForceIsNormal/0-box1-box2' (4..4)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_ForceIsPositive/0-box1-box2' (4..4)  type:ineq  order:0  target:[]  scale:[100]
#     TASK 'F_fex_Force/1-box1-box2' ()  type:sos  order:1  target:[]  scale:[0.01]
#     TASK 'F_fex_Force/0-box1-box2' (4..4)  type:sos  order:0  target:[]  scale:[0.01]
#     TASK 'F_fex_POA/1-box1-box2' ()  type:sos  order:1  target:[]  scale:[0.01]
#     TASK 'F_fex_POAzeroRelVel/1-box1-box2' ()  type:sos  order:1  target:[]  scale:[0.1]
#     TASK 'F_TotalForce/0-box1' (4..5)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_fex_POASurfaceDistance/0-box0-box1' (4..5)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_POASurfaceDistance/0-box0-box1' (4..5)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_PairCollision/0-box0-box1' (4..5)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_ForceIsNormal/0-box0-box1' (4..5)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_ForceIsPositive/0-box0-box1' (4..5)  type:ineq  order:0  target:[]  scale:[100]
#     TASK 'F_fex_Force/1-box0-box1' ()  type:sos  order:1  target:[]  scale:[0.01]
#     TASK 'F_fex_Force/0-box0-box1' (4..5)  type:sos  order:0  target:[]  scale:[0.01]
#     TASK 'F_fex_POA/1-box0-box1' ()  type:sos  order:1  target:[]  scale:[0.01]
#     TASK 'F_fex_POAzeroRelVel/1-box0-box1' (4..5)  type:sos  order:1  target:[]  scale:[0.1]
#     TASK 'F_PairCollision/0-L_endeff-box3' (3..3)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_PairCollision/0-box1-box3' (4..4)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_PairCollision/0-box2-box3' (4..4)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_TotalForce/0-box3' (4..4)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_fex_POASurfaceDistance/0-box1-box3' (4..4)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_POASurfaceDistance/0-box1-box3' (4..4)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_PairCollision/0-box1-box3' (4..4)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_ForceIsNormal/0-box1-box3' (4..4)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_ForceIsPositive/0-box1-box3' (4..4)  type:ineq  order:0  target:[]  scale:[100]
#     TASK 'F_fex_Force/1-box1-box3' ()  type:sos  order:1  target:[]  scale:[0.01]
#     TASK 'F_fex_Force/0-box1-box3' (4..4)  type:sos  order:0  target:[]  scale:[0.01]
#     TASK 'F_fex_POA/1-box1-box3' ()  type:sos  order:1  target:[]  scale:[0.01]
#     TASK 'F_fex_POAzeroRelVel/1-box1-box3' ()  type:sos  order:1  target:[]  scale:[0.1]
#     SWITCH  timeOfApplication=0  symbol=joint  jointType=free  fromId=54'R_endeff'  toId=2'box0'
#     SWITCH  timeOfApplication=1  symbol=joint  jointType=free  fromId=1'table'  toId=2'box0'
#     SWITCH  timeOfApplication=1  symbol=joint  jointType=free  fromId=30'L_endeff'  toId=3'box1'
#     SWITCH  timeOfApplication=2  symbol=joint  jointType=free  fromId=2'box0'  toId=3'box1'
#     SWITCH  timeOfApplication=3  symbol=joint  jointType=free  fromId=54'R_endeff'  toId=4'box2'
#     SWITCH  timeOfApplication=4  symbol=joint  jointType=free  fromId=3'box1'  toId=4'box2'
#     SWITCH  timeOfApplication=3  symbol=joint  jointType=free  fromId=30'L_endeff'  toId=5'box3'
#     SWITCH  timeOfApplication=4  symbol=joint  jointType=free  fromId=3'box1'  toId=5'box3'
#     SWITCH  timeOfApplication=2  symbol=addContact  jointType=init  fromId=2'box0'  toId=3'box1'
#     SWITCH  timeOfApplication=4  symbol=delContact  jointType=init  fromId=2'box0'  toId=3'box1'
#     SWITCH  timeOfApplication=4  symbol=addContact  jointType=init  fromId=3'box1'  toId=4'box2'
#     SWITCH  timeOfApplication=5  symbol=delContact  jointType=init  fromId=3'box1'  toId=4'box2'
#     SWITCH  timeOfApplication=4  symbol=addContact  jointType=init  fromId=2'box0'  toId=3'box1'
#     SWITCH  timeOfApplication=4  symbol=addContact  jointType=init  fromId=3'box1'  toId=5'box3'
#     SWITCH  timeOfApplication=5  symbol=delContact  jointType=init  fromId=3'box1'  toId=5'box3'
# {F_qItself/1-#28:{ order:1, type:sos, sos:0.0512905 },
# F_qQuaternionNorms/0-#56:{ order:0, type:eq, eq:0.0341545 },
# F_Pose/1-box0:{ order:1, type:eq, eq:0.0517742 },
# F_PoseRel/1-box0-R_endeff:{ order:1, type:eq, eq:0.0705358 },
# F_qZeroVel/1-box0:{ order:1, type:eq, eq:0.221779 },
# F_qZeroVel/1-box1:{ order:1, type:eq },
# F_Pose/1-box1:{ order:1, type:eq, eq:0.0155401 },
# F_PoseRel/1-box1-L_endeff:{ order:1, type:eq, eq:0.036345 },
# F_qZeroVel/1-box1:{ order:1, type:eq, eq:0.179591 },
# F_Pose/1-box2:{ order:1, type:eq, eq:0.0105759 },
# F_PoseRel/1-box2-R_endeff:{ order:1, type:eq, eq:0.0815726 },
# F_qZeroVel/1-box2:{ order:1, type:eq, eq:0.00425377 },
# F_Pose/1-box3:{ order:1, type:eq, eq:0.00450192 },
# F_PoseRel/1-box3-L_endeff:{ order:1, type:eq, eq:0.0325614 },
# F_PoseRel/1-box3-box1:{ order:1, type:eq, eq:0.00060398 },
# F_PairCollision/0-R_endeff-box0:{ order:0, type:eq, eq:0.136777 },
# F_PairCollision/0-table-box0:{ order:0, type:eq, eq:0.0058727 },
# F_PairCollision/0-L_endeff-box1:{ order:0, type:eq, eq:0.0216076 },
# F_PairCollision/0-box0-box1:{ order:0, type:eq, eq:0.101577 },
# F_TotalForce/0-box1:{ order:0, type:eq, eq:0.035291 },
# F_fex_POASurfaceDistance/0-box0-box1:{ order:0, type:eq, eq:0.0206134 },
# F_fex_POASurfaceDistance/0-box0-box1:{ order:0, type:eq, eq:0.0506022 },
# F_PairCollision/0-box0-box1:{ order:0, type:eq, eq:0.0273208 },
# F_fex_ForceIsNormal/0-box0-box1:{ order:0, type:eq, eq:0.0326922 },
# F_fex_ForceIsPositive/0-box0-box1:{ order:0, type:ineq },
# F_fex_Force/1-box0-box1:{ order:1, type:sos },
# F_fex_Force/0-box0-box1:{ order:0, type:sos, sos:0.0002 },
# F_fex_POA/1-box0-box1:{ order:1, type:sos },
# F_fex_POAzeroRelVel/1-box0-box1:{ order:1, type:sos, sos:1.11366e-09 },
# F_PairCollision/0-R_endeff-box2:{ order:0, type:eq, eq:0.0308799 },
# F_PairCollision/0-box1-box2:{ order:0, type:eq, eq:0.00791361 },
# F_TotalForce/0-box2:{ order:0, type:eq, eq:0.0698176 },
# F_fex_POASurfaceDistance/0-box1-box2:{ order:0, type:eq, eq:0.00135565 },
# F_fex_POASurfaceDistance/0-box1-box2:{ order:0, type:eq, eq:0.0486076 },
# F_PairCollision/0-box1-box2:{ order:0, type:eq, eq:0.000791361 },
# F_fex_ForceIsNormal/0-box1-box2:{ order:0, type:eq, eq:0.0498484 },
# F_fex_ForceIsPositive/0-box1-box2:{ order:0, type:ineq },
# F_fex_Force/1-box1-box2:{ order:1, type:sos },
# F_fex_Force/0-box1-box2:{ order:0, type:sos, sos:9.99995e-05 },
# F_fex_POA/1-box1-box2:{ order:1, type:sos },
# F_fex_POAzeroRelVel/1-box1-box2:{ order:1, type:sos },
# F_TotalForce/0-box1:{ order:0, type:eq, eq:0.0302454 },
# F_fex_POASurfaceDistance/0-box0-box1:{ order:0, type:eq, eq:0.165111 },
# F_fex_POASurfaceDistance/0-box0-box1:{ order:0, type:eq, eq:0.188046 },
# F_PairCollision/0-box0-box1:{ order:0, type:eq, eq:0.0489837 },
# F_fex_ForceIsNormal/0-box0-box1:{ order:0, type:eq, eq:0.064878 },
# F_fex_ForceIsPositive/0-box0-box1:{ order:0, type:ineq },
# F_fex_Force/1-box0-box1:{ order:1, type:sos },
# F_fex_Force/0-box0-box1:{ order:0, type:sos, sos:0.000999998 },
# F_fex_POA/1-box0-box1:{ order:1, type:sos },
# F_fex_POAzeroRelVel/1-box0-box1:{ order:1, type:sos, sos:1.41423e-10 },
# F_PairCollision/0-L_endeff-box3:{ order:0, type:eq, eq:0.0214901 },
# F_PairCollision/0-box1-box3:{ order:0, type:eq, eq:0.00226197 },
# F_PairCollision/0-box2-box3:{ order:0, type:eq, eq:0.0100101 },
# F_TotalForce/0-box3:{ order:0, type:eq, eq:0.0538495 },
# F_fex_POASurfaceDistance/0-box1-box3:{ order:0, type:eq, eq:0.0472021 },
# F_fex_POASurfaceDistance/0-box1-box3:{ order:0, type:eq, eq:0.035458 },
# F_PairCollision/0-box1-box3:{ order:0, type:eq, eq:0.000226197 },
# F_fex_ForceIsNormal/0-box1-box3:{ order:0, type:eq, eq:0.0284273 },
# F_fex_ForceIsPositive/0-box1-box3:{ order:0, type:ineq },
# F_fex_Force/1-box1-box3:{ order:1, type:sos },
# F_fex_Force/0-box1-box3:{ order:0, type:sos, sos:9.99996e-05 },
# F_fex_POA/1-box1-box3:{ order:1, type:sos },
# F_fex_POAzeroRelVel/1-box1-box3:{ order:1, type:sos },
# sos:0.0526905,
# ineq:0,
# eq:2.08155,
# f:0}

# %%
print(nlp.report(6))
# Out:
# KOMO Problem:
#   x-dim:239  dual-dim:0
#   T:6 k:1 phases:6 stepsPerPhase:1 tau:2
#   #timeSlices:7 #totalDOFs:239 #frames:392
#     times:[2, 4, 6, 8, 10, 12]
#   computeCollisions:0
#     TASK 'F_qItself/1-#28' (-1..5)  type:sos  order:1  target:[]  scale:[0.141421, 0.141421, 0.141421, 0.141421, 0.141421, 0.141421, 0.141421, 0.141421, 0.141421, 0.141421, 0.141421, 0.141421, 0.141421, 0.141421]
#     TASK 'F_qQuaternionNorms/0-#56' (0..5)  type:eq  order:0  target:[]  scale:[3]
#     TASK 'F_Pose/1-box0' (-1..0)  type:eq  order:1  target:[]  scale:[100]
#     TASK 'F_PoseRel/1-box0-R_endeff' (0..1)  type:eq  order:1  target:[]  scale:[100]
#     TASK 'F_qZeroVel/1-box0' (1..5)  type:eq  order:1  target:[]  scale:[10]
#     TASK 'F_qZeroVel/1-box1' ()  type:eq  order:1  target:[]  scale:[10]
#     TASK 'F_Pose/1-box1' (0..1)  type:eq  order:1  target:[]  scale:[100]
#     TASK 'F_PoseRel/1-box1-L_endeff' (1..2)  type:eq  order:1  target:[]  scale:[100]
#     TASK 'F_qZeroVel/1-box1' (2..5)  type:eq  order:1  target:[]  scale:[10]
#     TASK 'F_Pose/1-box2' (2..3)  type:eq  order:1  target:[]  scale:[100]
#     TASK 'F_PoseRel/1-box2-R_endeff' (3..4)  type:eq  order:1  target:[]  scale:[100]
#     TASK 'F_qZeroVel/1-box2' (4..5)  type:eq  order:1  target:[]  scale:[10]
#     TASK 'F_Pose/1-box3' (2..3)  type:eq  order:1  target:[]  scale:[100]
#     TASK 'F_PoseRel/1-box3-L_endeff' (3..4)  type:eq  order:1  target:[]  scale:[100]
#     TASK 'F_PoseRel/1-box3-box1' (4..5)  type:eq  order:1  target:[]  scale:[100]
#     TASK 'F_PairCollision/0-R_endeff-box0' (0..0)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_PairCollision/0-table-box0' (1..1)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_PairCollision/0-L_endeff-box1' (1..1)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_PairCollision/0-box0-box1' (2..2)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_TotalForce/0-box1' (2..3)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_fex_POASurfaceDistance/0-box0-box1' (2..3)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_POASurfaceDistance/0-box0-box1' (2..3)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_PairCollision/0-box0-box1' (2..3)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_ForceIsNormal/0-box0-box1' (2..3)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_ForceIsPositive/0-box0-box1' (2..3)  type:ineq  order:0  target:[]  scale:[100]
#     TASK 'F_fex_Force/1-box0-box1' ()  type:sos  order:1  target:[]  scale:[0.01]
#     TASK 'F_fex_Force/0-box0-box1' (2..3)  type:sos  order:0  target:[]  scale:[0.01]
#     TASK 'F_fex_POA/1-box0-box1' ()  type:sos  order:1  target:[]  scale:[0.01]
#     TASK 'F_fex_POAzeroRelVel/1-box0-box1' (2..3)  type:sos  order:1  target:[]  scale:[0.1]
#     TASK 'F_PairCollision/0-R_endeff-box2' (3..3)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_PairCollision/0-box1-box2' (4..4)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_TotalForce/0-box2' (4..4)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_fex_POASurfaceDistance/0-box1-box2' (4..4)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_POASurfaceDistance/0-box1-box2' (4..4)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_PairCollision/0-box1-box2' (4..4)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_ForceIsNormal/0-box1-box2' (4..4)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_ForceIsPositive/0-box1-box2' (4..4)  type:ineq  order:0  target:[]  scale:[100]
#     TASK 'F_fex_Force/1-box1-box2' ()  type:sos  order:1  target:[]  scale:[0.01]
#     TASK 'F_fex_Force/0-box1-box2' (4..4)  type:sos  order:0  target:[]  scale:[0.01]
#     TASK 'F_fex_POA/1-box1-box2' ()  type:sos  order:1  target:[]  scale:[0.01]
#     TASK 'F_fex_POAzeroRelVel/1-box1-box2' ()  type:sos  order:1  target:[]  scale:[0.1]
#     TASK 'F_TotalForce/0-box1' (4..5)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_fex_POASurfaceDistance/0-box0-box1' (4..5)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_POASurfaceDistance/0-box0-box1' (4..5)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_PairCollision/0-box0-box1' (4..5)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_ForceIsNormal/0-box0-box1' (4..5)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_ForceIsPositive/0-box0-box1' (4..5)  type:ineq  order:0  target:[]  scale:[100]
#     TASK 'F_fex_Force/1-box0-box1' ()  type:sos  order:1  target:[]  scale:[0.01]
#     TASK 'F_fex_Force/0-box0-box1' (4..5)  type:sos  order:0  target:[]  scale:[0.01]
#     TASK 'F_fex_POA/1-box0-box1' ()  type:sos  order:1  target:[]  scale:[0.01]
#     TASK 'F_fex_POAzeroRelVel/1-box0-box1' (4..5)  type:sos  order:1  target:[]  scale:[0.1]
#     TASK 'F_PairCollision/0-L_endeff-box3' (3..3)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_PairCollision/0-box1-box3' (4..4)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_PairCollision/0-box2-box3' (4..4)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_TotalForce/0-box3' (4..4)  type:eq  order:0  target:[]  scale:[100]
#     TASK 'F_fex_POASurfaceDistance/0-box1-box3' (4..4)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_POASurfaceDistance/0-box1-box3' (4..4)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_PairCollision/0-box1-box3' (4..4)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_ForceIsNormal/0-box1-box3' (4..4)  type:eq  order:0  target:[]  scale:[10]
#     TASK 'F_fex_ForceIsPositive/0-box1-box3' (4..4)  type:ineq  order:0  target:[]  scale:[100]
#     TASK 'F_fex_Force/1-box1-box3' ()  type:sos  order:1  target:[]  scale:[0.01]
#     TASK 'F_fex_Force/0-box1-box3' (4..4)  type:sos  order:0  target:[]  scale:[0.01]
#     TASK 'F_fex_POA/1-box1-box3' ()  type:sos  order:1  target:[]  scale:[0.01]
#     TASK 'F_fex_POAzeroRelVel/1-box1-box3' ()  type:sos  order:1  target:[]  scale:[0.1]
#     SWITCH  timeOfApplication=0  symbol=joint  jointType=free  fromId=54'R_endeff'  toId=2'box0'
#     SWITCH  timeOfApplication=1  symbol=joint  jointType=free  fromId=1'table'  toId=2'box0'
#     SWITCH  timeOfApplication=1  symbol=joint  jointType=free  fromId=30'L_endeff'  toId=3'box1'
#     SWITCH  timeOfApplication=2  symbol=joint  jointType=free  fromId=2'box0'  toId=3'box1'
#     SWITCH  timeOfApplication=3  symbol=joint  jointType=free  fromId=54'R_endeff'  toId=4'box2'
#     SWITCH  timeOfApplication=4  symbol=joint  jointType=free  fromId=3'box1'  toId=4'box2'
#     SWITCH  timeOfApplication=3  symbol=joint  jointType=free  fromId=30'L_endeff'  toId=5'box3'
#     SWITCH  timeOfApplication=4  symbol=joint  jointType=free  fromId=3'box1'  toId=5'box3'
#     SWITCH  timeOfApplication=2  symbol=addContact  jointType=init  fromId=2'box0'  toId=3'box1'
#     SWITCH  timeOfApplication=4  symbol=delContact  jointType=init  fromId=2'box0'  toId=3'box1'
#     SWITCH  timeOfApplication=4  symbol=addContact  jointType=init  fromId=3'box1'  toId=4'box2'
#     SWITCH  timeOfApplication=5  symbol=delContact  jointType=init  fromId=3'box1'  toId=4'box2'
#     SWITCH  timeOfApplication=4  symbol=addContact  jointType=init  fromId=2'box0'  toId=3'box1'
#     SWITCH  timeOfApplication=4  symbol=addContact  jointType=init  fromId=3'box1'  toId=5'box3'
#     SWITCH  timeOfApplication=5  symbol=delContact  jointType=init  fromId=3'box1'  toId=5'box3'
# {F_qItself/1-#28:{ order:1, type:sos, sos:0.0512905 },
# F_qQuaternionNorms/0-#56:{ order:0, type:eq, eq:0.0341545 },
# F_Pose/1-box0:{ order:1, type:eq, eq:0.0517742 },
# F_PoseRel/1-box0-R_endeff:{ order:1, type:eq, eq:0.0705358 },
# F_qZeroVel/1-box0:{ order:1, type:eq, eq:0.221779 },
# F_qZeroVel/1-box1:{ order:1, type:eq },
# F_Pose/1-box1:{ order:1, type:eq, eq:0.0155401 },
# F_PoseRel/1-box1-L_endeff:{ order:1, type:eq, eq:0.036345 },
# F_qZeroVel/1-box1:{ order:1, type:eq, eq:0.179591 },
# F_Pose/1-box2:{ order:1, type:eq, eq:0.0105759 },
# F_PoseRel/1-box2-R_endeff:{ order:1, type:eq, eq:0.0815726 },
# F_qZeroVel/1-box2:{ order:1, type:eq, eq:0.00425377 },
# F_Pose/1-box3:{ order:1, type:eq, eq:0.00450192 },
# F_PoseRel/1-box3-L_endeff:{ order:1, type:eq, eq:0.0325614 },
# F_PoseRel/1-box3-box1:{ order:1, type:eq, eq:0.00060398 },
# F_PairCollision/0-R_endeff-box0:{ order:0, type:eq, eq:0.136777 },
# F_PairCollision/0-table-box0:{ order:0, type:eq, eq:0.0058727 },
# F_PairCollision/0-L_endeff-box1:{ order:0, type:eq, eq:0.0216076 },
# F_PairCollision/0-box0-box1:{ order:0, type:eq, eq:0.101577 },
# F_TotalForce/0-box1:{ order:0, type:eq, eq:0.035291 },
# F_fex_POASurfaceDistance/0-box0-box1:{ order:0, type:eq, eq:0.0206134 },
# F_fex_POASurfaceDistance/0-box0-box1:{ order:0, type:eq, eq:0.0506022 },
# F_PairCollision/0-box0-box1:{ order:0, type:eq, eq:0.0273208 },
# F_fex_ForceIsNormal/0-box0-box1:{ order:0, type:eq, eq:0.0326922 },
# F_fex_ForceIsPositive/0-box0-box1:{ order:0, type:ineq },
# F_fex_Force/1-box0-box1:{ order:1, type:sos },
# F_fex_Force/0-box0-box1:{ order:0, type:sos, sos:0.0002 },
# F_fex_POA/1-box0-box1:{ order:1, type:sos },
# F_fex_POAzeroRelVel/1-box0-box1:{ order:1, type:sos, sos:1.11366e-09 },
# F_PairCollision/0-R_endeff-box2:{ order:0, type:eq, eq:0.0308799 },
# F_PairCollision/0-box1-box2:{ order:0, type:eq, eq:0.00791361 },
# F_TotalForce/0-box2:{ order:0, type:eq, eq:0.0698176 },
# F_fex_POASurfaceDistance/0-box1-box2:{ order:0, type:eq, eq:0.00135565 },
# F_fex_POASurfaceDistance/0-box1-box2:{ order:0, type:eq, eq:0.0486076 },
# F_PairCollision/0-box1-box2:{ order:0, type:eq, eq:0.000791361 },
# F_fex_ForceIsNormal/0-box1-box2:{ order:0, type:eq, eq:0.0498484 },
# F_fex_ForceIsPositive/0-box1-box2:{ order:0, type:ineq },
# F_fex_Force/1-box1-box2:{ order:1, type:sos },
# F_fex_Force/0-box1-box2:{ order:0, type:sos, sos:9.99995e-05 },
# F_fex_POA/1-box1-box2:{ order:1, type:sos },
# F_fex_POAzeroRelVel/1-box1-box2:{ order:1, type:sos },
# F_TotalForce/0-box1:{ order:0, type:eq, eq:0.0302454 },
# F_fex_POASurfaceDistance/0-box0-box1:{ order:0, type:eq, eq:0.165111 },
# F_fex_POASurfaceDistance/0-box0-box1:{ order:0, type:eq, eq:0.188046 },
# F_PairCollision/0-box0-box1:{ order:0, type:eq, eq:0.0489837 },
# F_fex_ForceIsNormal/0-box0-box1:{ order:0, type:eq, eq:0.064878 },
# F_fex_ForceIsPositive/0-box0-box1:{ order:0, type:ineq },
# F_fex_Force/1-box0-box1:{ order:1, type:sos },
# F_fex_Force/0-box0-box1:{ order:0, type:sos, sos:0.000999998 },
# F_fex_POA/1-box0-box1:{ order:1, type:sos },
# F_fex_POAzeroRelVel/1-box0-box1:{ order:1, type:sos, sos:1.41423e-10 },
# F_PairCollision/0-L_endeff-box3:{ order:0, type:eq, eq:0.0214901 },
# F_PairCollision/0-box1-box3:{ order:0, type:eq, eq:0.00226197 },
# F_PairCollision/0-box2-box3:{ order:0, type:eq, eq:0.0100101 },
# F_TotalForce/0-box3:{ order:0, type:eq, eq:0.0538495 },
# F_fex_POASurfaceDistance/0-box1-box3:{ order:0, type:eq, eq:0.0472021 },
# F_fex_POASurfaceDistance/0-box1-box3:{ order:0, type:eq, eq:0.035458 },
# F_PairCollision/0-box1-box3:{ order:0, type:eq, eq:0.000226197 },
# F_fex_ForceIsNormal/0-box1-box3:{ order:0, type:eq, eq:0.0284273 },
# F_fex_ForceIsPositive/0-box1-box3:{ order:0, type:ineq },
# F_fex_Force/1-box1-box3:{ order:1, type:sos },
# F_fex_Force/0-box1-box3:{ order:0, type:sos, sos:9.99996e-05 },
# F_fex_POA/1-box1-box3:{ order:1, type:sos },
# F_fex_POAzeroRelVel/1-box1-box3:{ order:1, type:sos },
# sos:0.0526905,
# ineq:0,
# eq:2.08155,
# f:0}

# %%
nlp = 0
benchmark = 0
solver = 0
